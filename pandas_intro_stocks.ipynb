# %%
# %load_ext cudf.pandas

# %%
import pandas as pd
import yfinance as yf

# %%
qqq = yf.Ticker("QQQ")

# %%
df = qqq.history(period='1mo')

# %%
df = df.drop(columns=['Dividends', 'Stock Splits', 'Capital Gains'])

# %%
df.plot(y=["Close"])
# Out:
# <Axes: xlabel='Date'>
